# %%
import pandas as pd
import numpy as np

# %%
train_file = pd.read_csv("train.csv")

# %%
train_file.head()
# Out:
#    id      Name  Gender   Age           City Working Professional or Student  \
# 0   0  Aaradhya  Female  49.0       Ludhiana            Working Professional
# 1   1     Vivan    Male  26.0       Varanasi            Working Professional
# 2   2    Yuvraj    Male  33.0  Visakhapatnam                         Student
# 3   3    Yuvraj    Male  22.0         Mumbai            Working Professional
# 4   4      Rhea  Female  30.0         Kanpur            Working Professional
#
#          Profession  Academic Pressure  Work Pressure  CGPA  \
# 0              Chef                NaN            5.0   NaN
# 1           Teacher                NaN            4.0   NaN
# 2               NaN                5.0            NaN  8.97
# 3           Teacher                NaN            5.0   NaN
# 4  Business Analyst                NaN            1.0   NaN
#
#    Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder1 = LabelEncoder()
label_encoder2 = LabelEncoder()
label_encoder3 = LabelEncoder()
label_encoder4 = LabelEncoder()
label_encoder5 = LabelEncoder()
label_encoder6 = LabelEncoder()
label_encoder7 = LabelEncoder()
train_file['Gender'] = pd.Series(label_encoder1.fit_transform(train_file['Gender']))
train_file['Working Professional or Student'] = pd.Series(label_encoder2.fit_transform(train_file['Working Professional or Student']))

# %%
train_file.head()
# Out:
#    id      Name  Gender   Age           City  Working Professional or Student  \
# 0   0  Aaradhya       0  49.0       Ludhiana                                1
# 1   1     Vivan       1  26.0       Varanasi                                1
# 2   2    Yuvraj       1  33.0  Visakhapatnam                                0
# 3   3    Yuvraj       1  22.0         Mumbai                                1
# 4   4      Rhea       0  30.0         Kanpur                                1
#
#          Profession  Academic Pressure  Work Pressure  CGPA  \
# 0              Chef                NaN            5.0   NaN
# 1           Teacher                NaN            4.0   NaN
# 2               NaN                5.0            NaN  8.97
# 3           Teacher                NaN            5.0   NaN
# 4  Business Analyst                NaN            1.0   NaN
#
#    Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# ...

# %% [markdown]
# ### Working with the df['City'] column

# %%
df = train_file['City'].value_counts()
# plt.bar(list(df.index), list(df.values), width = 0.6)
# plt.xticks(rotation=90, ha='right')  # 'ha' stands for horizontal alignment

# # Add some padding at the bottom to prevent label cutoff
# plt.subplots_adjust(bottom=0.2)
# plt.tight_layout()
plt.figure(figsize=(20, 6))  # Wider figure

# Create wider spaces between bars
x = np.arange(len(df)) * 2  # Multiply by 2 for more space
plt.bar(x, list(df.values), width=0.8)

# Adjust x-ticks to match new spacing
plt.xticks(x, list(df.index), rotation=45, ha='right')

plt.tight_layout()

# %%
df.index.unique()
# Out:
# Index(['Kalyan', 'Patna', 'Vasai-Virar', 'Kolkata', 'Ahmedabad', 'Meerut',
#        'Ludhiana', 'Pune', 'Rajkot', 'Visakhapatnam', 'Srinagar', 'Mumbai',
#        'Indore', 'Agra', 'Surat', 'Varanasi', 'Vadodara', 'Hyderabad',
#        'Kanpur', 'Jaipur', 'Thane', 'Lucknow', 'Nagpur', 'Bangalore',
#        'Chennai', 'Ghaziabad', 'Delhi', 'Bhopal', 'Faridabad', 'Nashik',
#        'Mihir', 'Nandini', 'Mahi', 'Vidya', 'City', 'Pratyush', 'Harsha',
#        'Saanvi', 'Bhavna', 'Molkata', 'MCA', 'M.Com', 'Atharv', 'Nalini',
#        'Keshav', 'Ayush', 'M.Tech', 'Researcher', 'Vaishnavi', 'Chhavi',
#        'Parth', 'Vidhi', 'Tushar', 'MSc', 'No', 'Rashi', 'ME', 'Ishanabad',
#        'Armaan', 'Kagan', 'Kashish', 'Ithal', 'Nalyan', 'Dhruv', 'Galesabad',
#        'Itheg', 'Aaradhya', 'Pooja', 'Khushi', 'Khaziabad', 'Jhanvi', 'Kibara',
#        'Harsh', 'Reyansh', 'Morena', 'Less Delhi', 'Malyansh', 'Aditya',
#        'Plata', 'Aishwarya', '3.0', 'Less than 5 Kalyan', 'Krishna', 'Mira',
# ...

# %%
train_file['City'].loc[train_file['City'] == 'Molkata'] = 'Kolkata'
train_file['City'].loc[train_file['City'] == 'Tolkata'] = 'Kolkata'
train_file['City'].loc[train_file['City'] == 'Less Delhi'] = 'Delhi'
train_file['City'].loc[train_file['City'] == 'Nalyan'] = 'Kalyan'
train_file['City'].loc[train_file['City'] == 'Less than 5 Kalyan'] = 'Kalyan'
train_file['City'].loc[train_file['City'] == 'Galesabad'] = 'Ghaziabad'
train_file['City'].loc[train_file['City'] == 'Tolkata'] = 'Kolkata'
train_file['City'].loc[train_file['City'] == 'Khaziabad'] = 'Ghaziabad'
# Out:
# C:\Users\amazi\AppData\Local\Temp\ipykernel_14884\2378593240.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   train_file['City'].loc[train_file['City'] == 'Molkata'] = 'Kolkata'
# ...

# %%
threshold = 10
column_to_check = 'City'

# Get value counts
value_counts = train_file[column_to_check].value_counts()

# Get values that meet threshold
values_to_keep = value_counts[value_counts >= threshold].index

# Filter dataframe
train_file = train_file[train_file[column_to_check].isin(values_to_keep)]

# %%
train_file['City'].value_counts().sum()
# Out:
# 140610

# %%
train_file['City'] = label_encoder3.fit_transform(train_file['City'])

# %%
train_file.drop(['id', 'Name'], axis = 1, inplace=True)

# %%
train_file.head()
# Out:
#    Gender   Age  City  Working Professional or Student        Profession  \
# 0       0  49.0    15                                1              Chef
# 1       1  26.0    27                                1           Teacher
# 2       1  33.0    29                                0               NaN
# 3       1  22.0    17                                1           Teacher
# 4       0  30.0    12                                1  Business Analyst
#
#    Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 0                NaN            5.0   NaN                 NaN
# 1                NaN            4.0   NaN                 NaN
# 2                5.0            NaN  8.97                 2.0
# 3                NaN            5.0   NaN                 NaN
# 4                NaN            1.0   NaN                 NaN
#
#    Job Satisfaction     Sleep Duration Dietary Habits   Degree  \
# 0               2.0  More than 8 hours        Healthy      BHM
# ...

# %% [markdown]
# ### Working with the other binary columns

# %%
train_file['Have you ever had suicidal thoughts ?'] = label_encoder4.fit_transform(train_file['Have you ever had suicidal thoughts ?'])
train_file['Family History of Mental Illness'] = label_encoder5.fit_transform(train_file['Family History of Mental Illness'])

# %%
train_file.head()
# Out:
#    Gender   Age  City  Working Professional or Student        Profession  \
# 0       0  49.0    15                                1              Chef
# 1       1  26.0    27                                1           Teacher
# 2       1  33.0    29                                0               NaN
# 3       1  22.0    17                                1           Teacher
# 4       0  30.0    12                                1  Business Analyst
#
#    Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 0                NaN            5.0   NaN                 NaN
# 1                NaN            4.0   NaN                 NaN
# 2                5.0            NaN  8.97                 2.0
# 3                NaN            5.0   NaN                 NaN
# 4                NaN            1.0   NaN                 NaN
#
#    Job Satisfaction     Sleep Duration Dietary Habits   Degree  \
# 0               2.0  More than 8 hours        Healthy      BHM
# ...

# %% [markdown]
# ### Working with contiguous valued columns

# %%
train_file['Work/Study Hours'].unique(), train_file['Financial Stress'].unique()
# Out:
# (array([ 1.,  7.,  3., 10.,  9.,  6.,  8.,  2.,  0.,  5., 12.,  4., 11.]),
#  array([ 2.,  3.,  1.,  4.,  5., nan]))

# %%
train_file = train_file.loc[train_file['Financial Stress'].isna() == False]

# %% [markdown]
# ### Working with Sleep Duration, Dietary Habits, and Degree

# %%
train_file['Sleep Duration'].unique(), train_file['Dietary Habits'].unique(), train_file['Degree'].unique()
# Out:
# (array(['More than 8 hours', 'Less than 5 hours', '5-6 hours', '7-8 hours',
#         'Sleep_Duration', '1-2 hours', '6-8 hours', '4-6 hours',
#         '6-7 hours', '10-11 hours', '8-9 hours', '40-45 hours',
#         '9-11 hours', '2-3 hours', '3-4 hours', 'Moderate', '55-66 hours',
#         '4-5 hours', '9-6 hours', '1-3 hours', 'Indore', '45', '1-6 hours',
#         '35-36 hours', '8 hours', 'No', '10-6 hours', 'than 5 hours',
#         '49 hours', 'Unhealthy', 'Work_Study_Hours', '3-6 hours',
#         '45-48 hours', '9-5', 'Pune', '9-5 hours'], dtype=object),
#  array(['Healthy', 'Unhealthy', 'Moderate', 'Yes', 'Pratham', 'BSc',
#         'Gender', '3', 'More Healthy', 'Less than Healthy', 'Mihir', '1.0',
#         'Hormonal', 'Electrician', nan, 'No Healthy', 'Less Healthy',
#         'M.Tech', 'Vegas', 'No', 'Male', 'Indoor', 'Class 12', '2'],
#        dtype=object),
#  array(['BHM', 'LLB', 'B.Pharm', 'BBA', 'MCA', 'MD', 'BSc', 'ME', 'B.Arch',
# ...

# %%
df1 = train_file['Sleep Duration'].value_counts()
# plt.bar(list(df.index), list(df.values), width = 0.6)
# plt.xticks(rotation=90, ha='right')  # 'ha' stands for horizontal alignment

# # Add some padding at the bottom to prevent label cutoff
# plt.subplots_adjust(bottom=0.2)
# plt.tight_layout()
plt.figure(figsize=(20, 6))  # Wider figure

# Create wider spaces between bars
x = np.arange(len(df1)) * 2  # Multiply by 2 for more space
plt.bar(x, list(df1.values), width=0.8)

# Adjust x-ticks to match new spacing
plt.xticks(x, list(df1.index), rotation=45, ha='right')

plt.tight_layout()

# %%
threshold1 = 2
column_to_check1 = 'Sleep Duration'

# Get value counts
value_counts1 = train_file[column_to_check1].value_counts()

# Get values that meet threshold
values_to_keep1 = value_counts1[value_counts1 >= threshold1].index

# Filter dataframe
train_file = train_file[train_file[column_to_check1].isin(values_to_keep1)]

# %%
train_file['Sleep Duration'].loc[train_file['Sleep Duration'] == '2-3 hours'] = 'Less than 6 hours'
train_file['Sleep Duration'].loc[train_file['Sleep Duration'] == '3-4 hours'] = 'Less than 6 hours'
train_file['Sleep Duration'].loc[train_file['Sleep Duration'] == '4-5 hours'] = 'Less than 6 hours'
train_file['Sleep Duration'].loc[train_file['Sleep Duration'] == '4-6 hours'] = 'Less than 6 hours'
train_file['Sleep Duration'].loc[train_file['Sleep Duration'] == '1-6 hours'] = 'Less than 6 hours'
train_file['Sleep Duration'].loc[train_file['Sleep Duration'] == '45'] = 'Less than 6 hours'
train_file['Sleep Duration'].loc[train_file['Sleep Duration'] == '5-6 hours'] = 'Less than 6 hours'
train_file['Sleep Duration'].loc[train_file['Sleep Duration'] == 'Less than 5 hours'] = 'Less than 6 hours'
train_file['Sleep Duration'].loc[train_file['Sleep Duration'] == '8-9 hours'] = 'More than 8 hours'
train_file['Sleep Duration'].loc[train_file['Sleep Duration'] == '9-11 hours'] = 'More than 8 hours'
train_file['Sleep Duration'].loc[train_file['Sleep Duration'] == '10-11 hours'] = 'More than 8 hours'
train_file['Sleep Duration'].loc[train_file['Sleep Duration'] == '6-7 hours'] = 'Btwn 6 and 8 hours'
train_file['Sleep Duration'].loc[train_file['Sleep Duration'] == '6-8 hours'] = 'Btwn 6 and 8 hours'
train_file['Sleep Duration'].loc[train_file['Sleep Duration'] == '7-8 hours'] = 'Btwn 6 and 8 hours'
# Out:
# C:\Users\amazi\AppData\Local\Temp\ipykernel_14884\771724748.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   train_file['Sleep Duration'].loc[train_file['Sleep Duration'] == '2-3 hours'] = 'Less than 6 hours'
# ...

# %%
train_file = train_file[(train_file['Sleep Duration'] != 'No') & (train_file['Sleep Duration'] != 'Sleep_Duration') & (train_file['Sleep Duration'] != 'Unhealthy')]

# %%
train_file['Sleep Duration'].value_counts().sum()
# Out:
# 140580

# %%
df2 = train_file['Dietary Habits'].value_counts()
# plt.bar(list(df.index), list(df.values), width = 0.6)
# plt.xticks(rotation=90, ha='right')  # 'ha' stands for horizontal alignment

# # Add some padding at the bottom to prevent label cutoff
# plt.subplots_adjust(bottom=0.2)
# plt.tight_layout()
plt.figure(figsize=(20, 6))  # Wider figure

# Create wider spaces between bars
x = np.arange(len(df2)) * 2  # Multiply by 2 for more space
plt.bar(x, list(df2.values), width=0.8)

# Adjust x-ticks to match new spacing
plt.xticks(x, list(df2.index), rotation=45, ha='right')

plt.tight_layout()

# %%
train_file['Dietary Habits'].loc[train_file['Dietary Habits'] == 'More Healthy'] = 'Healthy'
train_file['Dietary Habits'].loc[train_file['Dietary Habits'] == 'No Healthy'] = 'Unhealthy'
train_file['Dietary Habits'].loc[train_file['Dietary Habits'] == 'Less Healthy'] = 'Moderate'
train_file['Dietary Habits'].loc[train_file['Dietary Habits'] == 'Less than Healthy'] = 'Moderate'
train_file['Dietary Habits'].loc[train_file['Dietary Habits'] == 'Yes'] = 'Healthy'
train_file['Dietary Habits'].loc[train_file['Dietary Habits'] == 'No'] = 'Unhealthy'
# Out:
# C:\Users\amazi\AppData\Local\Temp\ipykernel_14884\2330937139.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   train_file['Dietary Habits'].loc[train_file['Dietary Habits'] == 'More Healthy'] = 'Healthy'
# ...

# %%
threshold1 = 2
column_to_check2 = 'Dietary Habits'

# Get value counts
value_counts2 = train_file[column_to_check2].value_counts()

# Get values that meet threshold
values_to_keep2 = value_counts2[value_counts2 >= threshold1].index

# Filter dataframe
train_file = train_file[train_file[column_to_check2].isin(values_to_keep2)]

# %%
train_file['Dietary Habits'].value_counts().sum()
# Out:
# 140562

# %%
df3 = train_file['Degree'].value_counts()
# plt.bar(list(df.index), list(df.values), width = 0.6)
# plt.xticks(rotation=90, ha='right')  # 'ha' stands for horizontal alignment

# # Add some padding at the bottom to prevent label cutoff
# plt.subplots_adjust(bottom=0.2)
# plt.tight_layout()
plt.figure(figsize=(20, 6))  # Wider figure

# Create wider spaces between bars
x = np.arange(len(df3)) * 2  # Multiply by 2 for more space
plt.bar(x, list(df3.values), width=0.8)

# Adjust x-ticks to match new spacing
plt.xticks(x, list(df3.index), rotation=45, ha='right')

plt.tight_layout()

# %%
threshold3 = 3
column_to_check3 = 'Degree'

# Get value counts
value_counts3 = train_file[column_to_check3].value_counts()

# Get values that meet threshold
values_to_keep3 = value_counts3[value_counts3 >= threshold3].index

# Filter dataframe
train_file = train_file[train_file[column_to_check3].isin(values_to_keep3)]

# %%
train_file['Degree'].loc[train_file['Degree'] == 'B.Sc'] = 'BSc'
train_file['Degree'].loc[train_file['Degree'] == 'Bsc'] = 'BSc'
train_file = train_file[(train_file['Degree'] != 'UX/UI Designer') & (train_file['Degree'] != 'M') & (train_file['Degree'] != 'Kalyan')]
# Out:
# C:\Users\amazi\AppData\Local\Temp\ipykernel_14884\4275666349.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   train_file['Degree'].loc[train_file['Degree'] == 'B.Sc'] = 'BSc'
# ...

# %%
train_file['Degree'].value_counts().sum()
# Out:
# 140455

# %%
train_file['Degree'].value_counts()
# Out:
# Degree
# Class 12    14720
# B.Ed        11684
# B.Arch       8736
# B.Com        8108
# B.Pharm      5849
# BCA          5730
# M.Ed         5663
# MCA          5226
# BBA          5028
# BSc          5021
# MSc          4873
# LLM          4645
# M.Pharm      4534
# M.Tech       4471
# B.Tech       4423
# LLB          4342
# BHM          4301
# MBA          3812
# BA           3744
# ME           3625
# MD           3379
# MHM          3284
# PhD          3102
# BE           3100
# M.Com        3090
# MBBS         3077
# MA           2883
# M.Arch          5
# Name: count, dtype: int64

# %%
train_file['Degree'] = label_encoder6.fit_transform(train_file['Degree'])

# %% [markdown]
# ### Working with conditional columns

# %%
train_file['CGPA'].fillna(0.00)
train_file['Study Satisfaction'].fillna(0.)
train_file['Job Satisfaction'].fillna(0.)
train_file['Work Pressure'].fillna(0.)
train_file['Academic Pressure'].fillna(0.)
# Out:
# 0         0.0
# 1         0.0
# 2         5.0
# 3         0.0
# 4         0.0
#          ...
# 140695    0.0
# 140696    0.0
# 140697    0.0
# 140698    0.0
# 140699    4.0
# Name: Academic Pressure, Length: 140455, dtype: float64

# %%
train_file['Profession'].unique()
# Out:
# array(['Chef', 'Teacher', nan, 'Business Analyst', 'Finanancial Analyst',
#        'Chemist', 'Electrician', 'Software Engineer', 'Data Scientist',
#        'Plumber', 'Marketing Manager', 'Accountant', 'Entrepreneur',
#        'HR Manager', 'UX/UI Designer', 'Content Writer',
#        'Educational Consultant', 'Civil Engineer', 'Manager',
#        'Pharmacist', 'Financial Analyst', 'Architect',
#        'Mechanical Engineer', 'Customer Support', 'Consultant', 'Judge',
#        'Researcher', 'Pilot', 'Graphic Designer', 'Travel Consultant',
#        'Digital Marketer', 'Lawyer', 'Research Analyst',
#        'Sales Executive', 'Doctor', 'Unemployed', 'Investment Banker',
#        'Family Consultant', 'B.Com', 'BE', 'Student', 'Yogesh', 'Dev',
#        'MBA', 'LLM', 'BCA', 'Academic', 'Profession', 'FamilyVirar',
#        'City Manager', 'BBA', 'Medical Doctor', 'Working Professional',
#        'MBBS', 'Patna', 'B.Ed', 'Nagpur', 'Moderate', 'M.Ed', 'Analyst',
# ...

# %%
df4 = train_file['Profession'].value_counts()
# plt.bar(list(df.index), list(df.values), width = 0.6)
# plt.xticks(rotation=90, ha='right')  # 'ha' stands for horizontal alignment

# # Add some padding at the bottom to prevent label cutoff
# plt.subplots_adjust(bottom=0.2)
# plt.tight_layout()
plt.figure(figsize=(20, 6))  # Wider figure

# Create wider spaces between bars
x = np.arange(len(df4)) * 2  # Multiply by 2 for more space
plt.bar(x, list(df4.values), width=0.8)

# Adjust x-ticks to match new spacing
plt.xticks(x, list(df4.index), rotation=45, ha='right')

plt.tight_layout()

# %%
df4[35:]
# Out:
# Profession
# Student                 7
# Academic                5
# Unemployed              3
# Profession              3
# Yogesh                  3
# BCA                     3
# MBA                     2
# LLM                     2
# PhD                     2
# Patna                   1
# Analyst                 1
# Pranav                  1
# Visakhapatnam           1
# M.Ed                    1
# Moderate                1
# Nagpur                  1
# B.Ed                    1
# City Manager            1
# MBBS                    1
# Working Professional    1
# Medical Doctor          1
# BBA                     1
# FamilyVirar             1
# Dev                     1
# BE                      1
# B.Com                   1
# Family Consultant       1
# Yuvraj                  1
# Name: count, dtype: int64

# %%
train_file.head()
# Out:
#    Gender   Age  City  Working Professional or Student        Profession  \
# 0       0  49.0    15                                1              Chef
# 1       1  26.0    27                                1           Teacher
# 2       1  33.0    29                                0               NaN
# 3       1  22.0    17                                1           Teacher
# 4       0  30.0    12                                1  Business Analyst
#
#    Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 0                NaN            5.0   NaN                 NaN
# 1                NaN            4.0   NaN                 NaN
# 2                5.0            NaN  8.97                 2.0
# 3                NaN            5.0   NaN                 NaN
# 4                NaN            1.0   NaN                 NaN
#
#    Job Satisfaction     Sleep Duration Dietary Habits  Degree  \
# 0               2.0  More than 8 hours        Healthy       9
# ...

# %%
len(train_file)
# Out:
# 140455

# %%
train_file['Profession'].loc[train_file['Profession'] == 'Medical Doctor'] = 'Doctor'
train_file['Profession'].loc[train_file['Profession'] == 'City Manager'] = 'Manager'
train_file['Profession'].loc[train_file['Profession'] == 'Family Consultant'] = 'Consultant'
train_file['Profession'].loc[train_file['Profession'] == 'Analyst'] = 'Research Analyst'
train_file['Profession'].loc[train_file['Profession'] == 'PhD'] = 'Research Analyst'
train_file['Profession'].loc[train_file['Profession'] == 'Academic'] = 'Research Analyst'
train_file['Profession'].loc[train_file['Profession'] == 'MBA'] = 'Manager'
train_file['Profession'].loc[train_file['Profession'] == 'MBBS'] = 'Doctor'
# Out:
# C:\Users\amazi\AppData\Local\Temp\ipykernel_14884\2275129332.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   train_file['Profession'].loc[train_file['Profession'] == 'Medical Doctor'] = 'Doctor'
# ...

# %%
train_file['Profession'].loc[train_file['Profession'] == 'Student'] = np.nan
# Out:
# C:\Users\amazi\AppData\Local\Temp\ipykernel_14884\2886497916.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   train_file['Profession'].loc[train_file['Profession'] == 'Student'] = np.nan
# ...

# %%
threshold = 5
placeholder = 'Teacher'

# Identify the values below the threshold
value_counts = train_file['Profession'].value_counts()
below_threshold = value_counts[value_counts < threshold].index

# Replace these values with the placeholder
train_file['Profession'] = train_file['Profession'].replace(below_threshold, placeholder)

# %%
train_file['Profession'] = train_file['Profession'].fillna('No Profession')

# %%
train_file.loc[train_file['Profession'] == 'Finanancial Analyst', "Profession"] = 'Financial Analyst'

# %%
STEM = ['Software Engineer', 'Chemist', 'Data Scientist', 'UX/UI Designer','Civil Engineer','Architect', 'Mechanical Engineer','Researcher','Research Analyst']
Business_Econ = ['Business Analyst', 'Financial Analyst', 'Marketing Manager', 'Accountant', 'Entrepreneur', 'HR Manager', 'Manager','Sales Executive','Investment Banker', 'Digital Marketer']
IntegralJobs = ['Teacher', 'Judge',  'Pilot', 'Lawyer','Doctor', 'Pharmacist']
Consulting = ['Travel Consultant', 'Consultant', 'Educational Consultant']
Arts = ['Graphic Designer', 'Chef',  'Content Writer']
OtherJobs = ['Electrician', 'Plumber', 'Customer Support']

# %%
train_file.loc[train_file['Profession'].isin(STEM), "Profession"] = 6
train_file.loc[train_file['Profession'].isin(Business_Econ), "Profession"] = 5
train_file.loc[train_file['Profession'].isin(IntegralJobs), "Profession"] = 4
train_file.loc[train_file['Profession'].isin(Consulting), "Profession"] = 3
train_file.loc[train_file['Profession'].isin(Arts), "Profession"] = 2
train_file.loc[train_file['Profession'].isin(OtherJobs), "Profession"] = 1
train_file.loc[train_file['Profession'].isna(), "Profession"] = 0
train_file.loc[train_file['Profession'] == 'No Profession', "Profession"] = 0

# %% [markdown]
# ### Dealing with test data

# %%
test_file = pd.read_csv('test.csv')

# %%
test_file['City'].unique()
# Out:
# array(['Visakhapatnam', 'Kolkata', 'Jaipur', 'Rajkot', 'Kalyan', 'Mumbai',
#        'Surat', 'Srinagar', 'Delhi', 'Lucknow', 'Thane', 'Meerut',
#        'Nagpur', 'Ghaziabad', 'Chennai', 'Varanasi', 'Indore', 'Pune',
#        'Hyderabad', 'Kanpur', 'Nashik', 'Bhopal', 'Faridabad',
#        'Bangalore', 'Vasai-Virar', 'Ludhiana', 'Patna', 'Vadodara',
#        'Ahmedabad', 'Agra', 'Malyan', 'Pratyush', 'Vidya',
#        'Less than 5 hours', 'Aditi', 'Keshav', 'Nalini', 'Mhopal', 'Avni',
#        'Ira', 'Vaishnavi', 'Bhavna', 'Lawyer', 'Thani', 'Hrithik', 'City',
#        'Unaly', 'Is Kanpur', 'Golkata', 'Less Delhi', 'Sara', 'Saurav',
#        'Vikram', 'Parth', 'Siddhesh', 'Vaikot', 'Leela', 'Chemist',
#        'San Vasai-Virar', 'No', 'More Delhi', 'Saanvi', 'Pratham',
#        'Vidhi', 'Abhinav', 'Rolkata', 'Ghopal', 'No.12'], dtype=object)

# %%
test_file['Profession'].loc[test_file['Profession'] == 'Surgeon'] = 'Doctor'
test_file['Profession'].loc[test_file['Profession'] == 'PhD'] = 'Research Analyst'
# Out:
# C:\Users\amazi\AppData\Local\Temp\ipykernel_14884\1261883180.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   test_file['Profession'].loc[test_file['Profession'] == 'Surgeon'] = 'Doctor'
# ...

# %%
test_file['Profession'].loc[test_file['Profession'] == 'Student'] = np.nan
# Out:
# C:\Users\amazi\AppData\Local\Temp\ipykernel_14884\2829322396.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   test_file['Profession'].loc[test_file['Profession'] == 'Student'] = np.nan
# ...

# %%
threshold = 5
placeholder = 'Teacher'

# Identify the values below the threshold
value_counts = test_file['Profession'].value_counts()
below_threshold = value_counts[value_counts < threshold].index

# Replace these values with the placeholder
test_file['Profession'] = test_file['Profession'].replace(below_threshold, placeholder)

# %%
test_file['Profession'] = test_file['Profession'].fillna('No Profession')

# %%
test_file.loc[test_file['Profession'] == 'Finanancial Analyst', "Profession"] = 'Financial Analyst'

# %%
test_file.loc[test_file['Profession'].isin(STEM), "Profession"] = 6
test_file.loc[test_file['Profession'].isin(Business_Econ), "Profession"] = 5
test_file.loc[test_file['Profession'].isin(IntegralJobs), "Profession"] = 4
test_file.loc[test_file['Profession'].isin(Consulting), "Profession"] = 3
test_file.loc[test_file['Profession'].isin(Arts), "Profession"] = 2
test_file.loc[test_file['Profession'].isin(OtherJobs), "Profession"] = 1
test_file.loc[test_file['Profession'].isna(), "Profession"] = 0
test_file.loc[test_file['Profession'] == 'No Profession', "Profession"] = 0

# %%
tdf = test_file['City'].value_counts()
# plt.bar(list(df.index), list(df.values), width = 0.6)
# plt.xticks(rotation=90, ha='right')  # 'ha' stands for horizontal alignment

# # Add some padding at the bottom to prevent label cutoff
# plt.subplots_adjust(bottom=0.2)
# plt.tight_layout()
plt.figure(figsize=(20, 6))  # Wider figure

# Create wider spaces between bars
x = np.arange(len(tdf)) * 2  # Multiply by 2 for more space
plt.bar(x, list(tdf.values), width=0.8)

# Adjust x-ticks to match new spacing
plt.xticks(x, list(tdf.index), rotation=45, ha='right')

plt.tight_layout()

# %%
threshold = 5
placeholder = 'Kalyan'

# Identify the values below the threshold
value_counts = test_file['City'].value_counts()
below_threshold = value_counts[value_counts < threshold].index

# Replace these values with the placeholder
test_file['City'] = test_file['City'].replace(below_threshold, placeholder)

# %%
test_file['City'].value_counts()
# Out:
# City
# Kalyan           4437
# Vasai-Virar      3897
# Patna            3888
# Kolkata          3726
# Ahmedabad        3677
# Meerut           3661
# Srinagar         3547
# Ludhiana         3545
# Rajkot           3450
# Visakhapatnam    3416
# Pune             3318
# Agra             3189
# Vadodara         3169
# Mumbai           3129
# Hyderabad        3123
# Surat            3090
# Varanasi         3052
# Indore           3040
# Kanpur           2978
# Jaipur           2874
# Lucknow          2860
# Thane            2835
# Nagpur           2748
# Bangalore        2707
# Chennai          2674
# Delhi            2536
# Ghaziabad        2486
# Bhopal           2370
# Faridabad        2196
# Nashik           2182
# Name: count, dtype: int64

# %%
test_file['Dietary Habits'].unique()
# Out:
# array(['Moderate', 'Healthy', 'Unhealthy', 'More Healthy', 'No', 'Indoor',
#        'Prachi', nan, 'Male', 'Less Healthy', 'Mealy', 'Resistant', 'MCA',
#        '5 Healthy', 'Academic', 'Educational', 'Soham', '5 Unhealthy',
#        'Vivaan', 'Raghav', '1.0', 'Naina', 'Kolkata'], dtype=object)

# %%
test_file['Dietary Habits'].loc[test_file['Dietary Habits'] == 'More Healthy'] = 'Healthy'
test_file['Dietary Habits'].loc[test_file['Dietary Habits'] == '5 Unhealthy'] = 'Unhealthy'
test_file['Dietary Habits'].loc[test_file['Dietary Habits'] == 'Less Healthy'] = 'Moderate'
test_file['Dietary Habits'].loc[test_file['Dietary Habits'] == 'Less than Healthy'] = 'Moderate'
test_file['Dietary Habits'].loc[test_file['Dietary Habits'] == '5 Healthy'] = 'Healthy'
test_file['Dietary Habits'].loc[test_file['Dietary Habits'] == 'No'] = 'Unhealthy'
# Out:
# C:\Users\amazi\AppData\Local\Temp\ipykernel_14884\2712788421.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   test_file['Dietary Habits'].loc[test_file['Dietary Habits'] == 'More Healthy'] = 'Healthy'
# ...

# %%
tdf = test_file['Dietary Habits'].value_counts()
# plt.bar(list(df.index), list(df.values), width = 0.6)
# plt.xticks(rotation=90, ha='right')  # 'ha' stands for horizontal alignment

# # Add some padding at the bottom to prevent label cutoff
# plt.subplots_adjust(bottom=0.2)
# plt.tight_layout()
plt.figure(figsize=(20, 6))  # Wider figure

# Create wider spaces between bars
x = np.arange(len(tdf)) * 2  # Multiply by 2 for more space
plt.bar(x, list(tdf.values), width=0.8)

# Adjust x-ticks to match new spacing
plt.xticks(x, list(tdf.index), rotation=45, ha='right')

plt.tight_layout()

# %%
threshold = 2
placeholder = 'Moderate'

# Identify the values below the threshold
value_counts = test_file['Dietary Habits'].value_counts()
below_threshold = value_counts[value_counts < threshold].index

# Replace these values with the placeholder
test_file['Dietary Habits'] = test_file['Dietary Habits'].replace(below_threshold, placeholder)

# %%
tdf = test_file['Sleep Duration'].value_counts()
# plt.bar(list(df.index), list(df.values), width = 0.6)
# plt.xticks(rotation=90, ha='right')  # 'ha' stands for horizontal alignment

# # Add some padding at the bottom to prevent label cutoff
# plt.subplots_adjust(bottom=0.2)
# plt.tight_layout()
plt.figure(figsize=(20, 6))  # Wider figure

# Create wider spaces between bars
x = np.arange(len(tdf)) * 2  # Multiply by 2 for more space
plt.bar(x, list(tdf.values), width=0.8)

# Adjust x-ticks to match new spacing
plt.xticks(x, list(tdf.index), rotation=45, ha='right')

plt.tight_layout()

# %%
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '2-3 hours'] = 'Less than 6 hours'
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '3-4 hours'] = 'Less than 6 hours'
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '4-5 hours'] = 'Less than 6 hours'
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '4-6 hours'] = 'Less than 6 hours'
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '1-6 hours'] = 'Less than 6 hours'
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '3-6 hours'] = 'Less than 6 hours'
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '1-2 hours'] = 'Less than 6 hours'
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '1-3 hours'] = 'Less than 6 hours'
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '45'] = 'Less than 6 hours'
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '5-6 hours'] = 'Less than 6 hours'
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == 'Less than 5 hours'] = 'Less than 6 hours'
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '8-9 hours'] = 'More than 8 hours'
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '9-11 hours'] = 'More than 8 hours'
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '10-11 hours'] = 'More than 8 hours'
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '6-7 hours'] = 'Btwn 6 and 8 hours'
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '6 hours'] = 'Btwn 6 and 8 hours'
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '6-8 hours'] = 'Btwn 6 and 8 hours'
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '7-8 hours'] = 'Btwn 6 and 8 hours'
test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '9-10 hours'] = 'More than 8 hours'
# Out:
# C:\Users\amazi\AppData\Local\Temp\ipykernel_14884\2333981593.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   test_file['Sleep Duration'].loc[test_file['Sleep Duration'] == '2-3 hours'] = 'Less than 6 hours'
# ...

# %%
threshold = 3
placeholder = 'Less than 6 hours'

# Identify the values below the threshold
value_counts = test_file['Sleep Duration'].value_counts()
below_threshold = value_counts[value_counts < threshold].index

# Replace these values with the placeholder
test_file['Sleep Duration'] = test_file['Sleep Duration'].replace(below_threshold, placeholder)

# %%
test_file.head()
# Out:
#        id     Name  Gender   Age           City  \
# 0  140700   Shivam    Male  53.0  Visakhapatnam
# 1  140701    Sanya  Female  58.0        Kolkata
# 2  140702     Yash    Male  53.0         Jaipur
# 3  140703   Nalini  Female  23.0         Rajkot
# 4  140704  Shaurya    Male  47.0         Kalyan
#
#   Working Professional or Student Profession  Academic Pressure  \
# 0            Working Professional          4                NaN
# 1            Working Professional          3                NaN
# 2            Working Professional          4                NaN
# 3                         Student          0                5.0
# 4            Working Professional          4                NaN
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            2.0   NaN                 NaN               5.0
# 1            2.0   NaN                 NaN               4.0
# 2            4.0   NaN                 NaN               1.0
# ...

# %%
test_file['City'] = label_encoder3.fit_transform(test_file['City'])

# %%
tdf = test_file['Degree'].value_counts()
# plt.bar(list(df.index), list(df.values), width = 0.6)
# plt.xticks(rotation=90, ha='right')  # 'ha' stands for horizontal alignment

# # Add some padding at the bottom to prevent label cutoff
# plt.subplots_adjust(bottom=0.2)
# plt.tight_layout()
plt.figure(figsize=(20, 6))  # Wider figure

# Create wider spaces between bars
x = np.arange(len(tdf)) * 2  # Multiply by 2 for more space
plt.bar(x, list(tdf.values), width=0.8)

# Adjust x-ticks to match new spacing
plt.xticks(x, list(tdf.index), rotation=45, ha='right')

plt.tight_layout()

# %%
tdf
# Out:
# Degree
# Class 12    9812
# B.Ed        7762
# B.Arch      6037
# B.Com       5439
# B.Pharm     3987
#             ...
# Bian           1
# Kavya          1
# M.M.Ed         1
# Vrinda         1
# BHCA           1
# Name: count, Length: 87, dtype: int64

# %%
test_file['Degree'].loc[test_file['Degree'] == 'Btech'] = 'B.Tech'
test_file['Degree'].loc[test_file['Degree'] == 'BTech'] = 'B.Tech'
test_file['Degree'].loc[test_file['Degree'] == 'BArch'] = 'B.Arch'
test_file['Degree'].loc[test_file['Degree'] == 'M'] = 'M.Ed'
test_file['Degree'].loc[test_file['Degree'] == 'B.Sc'] = 'BSc'
test_file['Degree'].loc[test_file['Degree'] == 'BPharm'] = 'B.Pharm'
test_file['Degree'].loc[test_file['Degree'] == 'MPharm'] = 'M.Pharm'
test_file['Degree'].loc[test_file['Degree'] == 'B._Pharm'] = 'B.Pharm'
test_file['Degree'].loc[test_file['Degree'] == 'B_Com'] = 'B.Com'
test_file['Degree'].loc[test_file['Degree'] == 'BHCA'] = 'BHM'
test_file['Degree'].loc[test_file['Degree'] == 'B B.Tech'] = 'B.Tech'
test_file['Degree'].loc[test_file['Degree'] == 'B BCA'] = 'BCA'
test_file['Degree'].loc[test_file['Degree'] == 'B.CA'] = 'BCA'
test_file['Degree'].loc[test_file['Degree'] == 'B'] = 'B.Ed'
test_file['Degree'].loc[test_file['Degree'] == 'BEd'] = 'B.Ed'
test_file['Degree'].loc[test_file['Degree'] == 'BH'] = 'BHM'
test_file['Degree'].loc[test_file['Degree'] == 'B.H'] = 'BHM'
test_file['Degree'].loc[test_file['Degree'] == 'GCA'] = 'BCA'
test_file['Degree'].loc[test_file['Degree'] == 'PCA'] = 'BCA'
test_file['Degree'].loc[test_file['Degree'] == 'RCA'] = 'BCA'
test_file['Degree'].loc[test_file['Degree'] == 'MPharm'] = 'M.Pharm'
test_file['Degree'].loc[test_file['Degree'] == 'S.Pharm'] = 'B.Pharm'
test_file['Degree'].loc[test_file['Degree'] == 'B.M.Com'] = 'B.Com'
test_file['Degree'].loc[test_file['Degree'] == 'B.BA'] = 'BBA'
# Out:
# C:\Users\amazi\AppData\Local\Temp\ipykernel_14884\204273560.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   test_file['Degree'].loc[test_file['Degree'] == 'Btech'] = 'B.Tech'
# ...

# %%
threshold = 3
placeholder = 'B.Ed'

# Identify the values below the threshold
value_counts = test_file['Degree'].value_counts()
below_threshold = value_counts[value_counts < threshold].index

# Replace these values with the placeholder
test_file['Degree'] = test_file['Degree'].replace(below_threshold, placeholder)

# %%
#test_file.head()
test_file['Gender'] = label_encoder1.fit_transform(test_file['Gender'])
test_file['Working Professional or Student'] = label_encoder2.fit_transform(test_file['Working Professional or Student'])
test_file['Degree'] = label_encoder6.fit_transform(test_file['Degree'])
test_file['Have you ever had suicidal thoughts ?'] = label_encoder4.fit_transform(test_file['Have you ever had suicidal thoughts ?'])
test_file['Family History of Mental Illness'] = label_encoder5.fit_transform(test_file['Family History of Mental Illness'])

# %%
test_file['Degree'].loc[test_file['Degree'] == 28]= 11
# Out:
# C:\Users\amazi\AppData\Local\Temp\ipykernel_14884\688856130.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   test_file['Degree'].loc[test_file['Degree'] == 28]= 11
# ...

# %%
train_file['Sleep Duration'] = label_encoder7.fit_transform(train_file['Sleep Duration'])
test_file['Sleep Duration'] = label_encoder7.fit_transform(test_file['Sleep Duration'])

# %%
label_encoder8 = LabelEncoder()
train_file['Dietary Habits'] = label_encoder7.fit_transform(train_file['Dietary Habits'])
test_file['Dietary Habits'] = label_encoder7.fit_transform(test_file['Dietary Habits'])

# %%
test_file_id = test_file['id'].copy(deep=True)

# %%
test_file.drop('id', axis = 1, inplace=True)

# %%
X_train = train_file.iloc[:,0:-1]
y_train = train_file['Depression']
X_test = test_file

# %%
bins = [0, 20, 37, 49, 60]
labels = [0, 1, 2, 3]
X_train['AgeGroup'] = pd.cut(X_train['Age'], bins=bins, labels=labels)
X_test['AgeGroup'] = pd.cut(X_train['Age'], bins=bins, labels=labels)

# %%
from xgboost import XGBClassifier

# %%
# model = XGBClassifier(
#     n_estimators = 100,
#     learning_rate=0.1,  # Step size shrinkage to prevent overfitting
#     max_depth=3,        # Maximum depth of trees
#     subsample=0.8,      # Fraction of samples used for fitting trees
#     colsample_bytree=0.8,  # Fraction of features used for each tree
    
#     # Regularization parameters
#     #reg_alpha=0,        # L1 regularization 
#     #reg_lambda=1,       # L2 regularization
    
#     # Additional parameters
#     random_state=42,    # For reproducibility
#     n_jobs=-1  
# )

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [50, 100, 150, 160],
    'learning_rate': [0.01, 0.05, 0.1, 0.3],
    'max_depth': [3, 5, 7, 9]
}

grid_search = GridSearchCV(
    estimator=XGBClassifier(random_state=42),
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

# %%
#X_train.drop(['Profession'], axis=1, inplace=True)

# %%
label_encoder10 = LabelEncoder()
X_train['AgeGroup'] = label_encoder10.fit_transform(X_train['AgeGroup'])
X_test['AgeGroup'] = label_encoder10.fit_transform(X_test['AgeGroup'])

# %%
X_train['Profession'] = X_train['Profession'].astype(int)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
# ...

# %%
X_test.drop(['Name'], axis= 1, inplace=True)

# %%
X_test['Profession'] = X_test['Profession'].astype(int)

# %%
y_pred = grid_search.predict(X_test)

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 160}

# %%
final_df = pd.DataFrame({
    'id':test_file_id,
    'Depression': y_pred
})

# %%
final_csv = final_df.to_csv('attempt15.csv', index=False)
